# %% [markdown]
# # SuperGLUE Task formats

# %% [markdown]
# ## Preliminaries

# %%
import torch
import torch.nn.functional as F
import os
import json
import sys
import gc
import time
import random
import re
from tqdm import tqdm 

from transformers import AutoTokenizer, AutoModelForCausalLM
model_name = "facebook/opt-125m"
model = AutoModelForCausalLM.from_pretrained(model_name).cuda()
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False, padding_side='left',)

def read_json(filepath: str) -> dict:
    with open(filepath, "r") as f:
        return json.load(f)
    
def read_jsonl(filepath: str) -> dict:
    data = []
    with open(filepath, "r") as f:
        for line in f.readlines():
            example = json.loads(line)
            data.append(example)
    return data

# %%
tasks = ["BoolQ", "CB", "COPA", "MultiRC", "ReCoRD", "RTE", "WiC", "WSC"]
data = {}
for task_name in tasks:
    path = os.path.join("/nethome/dhe83/mice/data", task_name)
    task = read_jsonl(os.path.join(path, "val.jsonl"))
    task = {x['idx']: x for x in task}
    data[task_name] = task

# %%
train = {}
for task_name in tasks:
    path = os.path.join("/nethome/dhe83/mice/data", task_name)
    task = read_jsonl(os.path.join(path, "train.jsonl"))
    task = {x['idx']: x for x in task}
    train[task_name] = task

# %%
# def batch_score(model, prompts, labels):
#     prompt_tokens = tokenizer(prompts, padding=True, return_tensors="pt", return_attention_mask=True).to("cuda:0")
#     pad_length = prompt_tokens.input_ids.shape[-1]
#     labels = tokenizer(labels, padding="max_length", max_length=pad_length, return_tensors="pt").to("cuda:0")
#     labels_mask = labels.attention_mask
# #     print("prompt_tokens", prompt_tokens)
# #     print("labels_mask", labels_mask)
#     with torch.no_grad():
#         logits = model(**prompt_tokens).logits
        
# #     print("logits", logits)
    
# #     print(prompt_tokens.input_ids)

#     sequence_logits = logits.log_softmax(-1).gather(-1, prompt_tokens.input_ids.unsqueeze(-1)).squeeze(-1)
# #     print("sequence_logits", sequence_logits)
#     labels_logits = labels_mask * sequence_logits
# #     print("labels_logits", labels_logits)
#     log_probs = labels_logits.sum(-1).to("cpu")
#     return log_probs

# %% [markdown]
# ## In-Context Aggregation

# %%
t = random.sample(sorted(data), k=400)s
train = {k: data[k] for k in t[:200]}
test = {k: data[k] for k in t[200:]}

prompt_map = {k: [tuple(random.sample(sorted(train), k=1)) for x in range(1)] for k in test.keys()}

# %%
results = {}
raw = {}
for test_id, train_ids in tqdm(prompt_map.items()):
    test = data[test_id]
    prompts = []
    labels = []
    for pair in train_ids:
        demonstrations = [data[i] for i in pair]
        p, l = COPA_few_shot(demonstrations, test)
        prompts.append(p)
        labels.append(l)
                
    prompts =[prompt for pair in prompts for prompt in pair]
    labels =[label for pair in labels for label in pair]
    log_probs = batch_score(model, prompts, labels)
    
    log_probs = log_probs.view(-1, 2)
    preds = log_probs.argmax(-1)
    
    pred = 0
    if preds.sum(-1) > preds.shape[0] / 2:
        pred = 1
    results[test_id] = pred
    raw[test_id] = preds

# %%
correct = 0
total = 0
for id, pred in results.items():
    if data[id]['label'] == pred:
        correct+=1
    total+=1

print(correct/total)

# %% [markdown]
# ## Zero Shot

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False, padding_side='left',pad_token="-")
results = {}
raw = {}
total = 0
correct = 0
for test_id, ex in tqdm(data.items()):
    prompts, labels = COPA_few_shot([], ex)
    
    print("prompts", prompts)
#     print("labels", labels)
          
    log_probs = batch_score(model, prompts, labels)
    print("log_probs, log_probs")
    log_probs = log_probs.view(-1, 2)
    print("viewed log_probs", log_probs)
    pred = log_probs.argmax(-1)
    print("pred", pred)
    
    if pred.item() == ex['label']:
#         print("pred.item()", pred.item())
#         print("label", ex['label'])
        correct +=1
    total+=1
            
    results[test_id] = pred.item()
    
#     print(log_probs)
#     break

    
print(correct/total)

# %% [markdown]
# ## BoolQ

# %%
data["ReCoRD"][5]
# Out:
# {'source': 'Daily mail',
#  'passage': {'text': "The wife of one of the\xa0San Bernardino victims believes shooter\xa0Syed Farook targeted her husband because he was a Jew. Jennifer Thalasinos said her husband\xa0Nicholas had discussed religion and Israel with his co-worker Farook, as well as whether Islam is a peaceful religion. It has previously been reported that Mr Thalasinos, a Messianic Jew who wore tzitzits and the Star of David, harbored strong views against radical Islam and was a staunch supporter of the right to bear arms. 'Because of my husband being a Messianic Jew and because of the discussions, I think the shooter was intending on getting my husband,' Mrs\xa0Thalasinos told Fox News.\n@highlight\nJennifer Thalasinos believes\xa0Syed Farook targeted her husband Nicholas\n@highlight\nHe had discussed Israel and religion with his co-worker Farook, she said\n@highlight\nMr Thalasinos and Farook may have argued on Facebook before attack",
#   'entities': [{'start': 23, 'end': 36},
#    {'start': 63, 'end': 73},
#    {'start': 113, 'end': 115},
#    {'start': 118, 'end': 136},
#    {'start': 155, 'end': 162},
#    {'start': 191, 'end': 196},
#    {'start': 217, 'end': 222},
#    {'start': 244, 'end': 248},
#    {'start': 314, 'end': 323},
#    {'start': 328, 'end': 340},
#    {'start': 368, 'end': 380},
#    {'start': 421, 'end': 425},
#    {'start': 513, 'end': 525},
#    {'start': 621, 'end': 630},
#    {'start': 637, 'end': 644},
#    {'start': 658, 'end': 676},
#    {'start': 687, 'end': 697}]},
#  'qas': [{'query': "'@placeholder is going to be going through more than we'll ever be able to understand and we hope this will help ease her life just a little.'",
#    'answers': [{'start': 118, 'end': 136, 'text': 'Jennifer Thalasinos'},
#     {'start': 658, 'end': 676, 'text': 'Jennifer Thalasinos'}],
#    'idx': 11}],
#  'idx': 5}

# %%
max_generated_len = 40
def format_BoolQ(ex: dict, in_context=False):
    prompt = f"Context: {ex['passage']}\nQuestion: {ex['question']}\nAnswer:"
    
    substitutions = ["no", "yes"]
    if in_context:
        prompt+=substitutions[ex['label']]
        
    return prompt

def format_CB(ex, in_context=False):
    return f"{ex['premise']}\nQuestion: {ex['hypothesis']}. True, False, or Neither?\nAnswer:"

def format_COPA(ex: dict, in_context=False):
    
    substitute = {"cause": "because", "effect": "so"}
    
    context = f"Context: {ex['premise'][:-1]} {substitute[ex['question']]} "
    
    if in_context:
        label = ex['choice1'] if ex['label'] == 0 else ex['choice2']
        return context + label
    
    else:
        prompts = [context + ex['choice1'], context + ex['choice2']]
        labels = [ex['choice1'], ex['choice2']]

        return prompts, labels

def format_MultiRC(ex, in_context=False):
    prompts = []
    labels = []
    substitutions = ["False", "True"]
    
    def format_answer(label, text):
        return f"[{substitutions[label]}] {text}"
    
    for question in ex['passage']["questions"]:
        for answer in question["answers"]:
            prompt = (f"READING COMPREHENSION ANSWER KEY\n{ex['passage']['text']}\n\n"
                        f"{question['question']}\n")
            prompts.append((prompt + format_answer(0, answer['text']), prompt + format_answer(1, answer['text'])))
            labels.append(prompt + format_answer(answer['label'], answer['text']))
            
    return prompts, labels

#TODO: 
def format_ReCoRD(ex, in_context=False):
    return (f"{ex['premise']}\n"
            f"question: {ex['hypothesis']}. true, false, or neither?")

def format_RTE(ex, in_context=False):
    return (f"{ex['premise']}\n"
            f"question: {ex['hypothesis']}. True or False?"
            f"answer:")

def format_WiC(ex, in_context=False):
    return (f"{ex['sentence1']}\n{ex['sentence2']}\n"
            f"question: Is the word \'{ex['word']}\' used in the same way in the two sentences above?"
            f"answer:")

#TODO:
def format_WSC(ex, in_context=False):
    return (f"Passage: {ex['text']}\n"
            f"Question: In the passage above, does the pronoun " 
            f"\"{ex['target']['span2_text']}\" refer to {ex['target']['span1_text']}?\n"
            f"Answer:")

def format_example(ex : dict, dataset: str, in_context=False):
    assert dataset in tasks
    
    templates = {"BoolQ": format_BoolQ,
                "CB": format_CB,
                "RTE": format_RTE,
                "WiC": format_WiC,
                "WSC": format_WSC}
    
    return templates[dataset](ex, in_context)

def format_few_shot(demonstrations, test, dataset):
    instructions = {"BoolQ": "Answer the question."}
    demonstrations = [format_example(ex, dataset, in_context=True) for ex in demonstrations]
    context = [instructions[dataset], *demonstrations]
    
    prompt = format_example(test, dataset)
    prompt = "\n\n".join([*context, prompt])
    return prompt

def COPA_few_shot(demonstrations, test):
    instruction = "Pick the more likely continuation to the following sentence."
    demonstrations = [format_COPA(ex, in_context=True) for ex in demonstrations]
    context = "\n".join([instruction, *demonstrations])
    
    prompts, labels = format_COPA(test)
    
    prompts = [("\n".join([context, prompt])) for prompt in prompts]
    return prompts, labels

def first_word(s):
    return "".join([c for c in re.split(" |\n",s.strip())[0] if str.isalpha(c)]).lower()

# %%
###

# %%
def zero_shot_inference(model, ex, dataset):
#     prompt = format_few_shot([], ex, dataset)
    prompt = format_example(ex, dataset)
    tokens = tokenizer(prompt, padding=True, return_tensors="pt").to('cuda:0')
    outputs = model.generate(
         **tokens,
         max_new_tokens=max_generated_len,
         temperature=0,
         return_dict_in_generate=True,
         output_scores=True,
         eos_token_id=198,  # special character 'ċ' (bytecode for new line?) NOTE use this for generation
    )
    output_text = tokenizer.decode(outputs.sequences.squeeze()[-max_generated_len:])
    res = first_word(output_text)    
    return res

def zero_shot_scoring(model, prompts):
    encoded_prompt = tokenizer(
        prompts,
        truncation=True,
        padding=True,
        return_tensors="pt",
    )
    encoded_prompt = encoded_prompt.to("cuda:0")
    with torch.no_grad():
        logits = model(**encoded_prompt,).logits
        
    labels_attention_mask = encoded_prompt["attention_mask"].unsqueeze(-1)
    masked_log_probs = labels_attention_mask.float() * torch.log_softmax(
        logits.float(), dim=-1
    )
    seq_token_log_probs = torch.gather(
        masked_log_probs, -1, encoded_prompt["input_ids"].unsqueeze(-1)
    )
    seq_token_log_probs = seq_token_log_probs.squeeze(dim=-1)
    seq_log_prob = seq_token_log_probs.sum(dim=-1).to("cpu")
    return seq_log_prob

# %% [markdown]
# ### Batch Operations

# %%
batch_size = 50
gen_len = 20
def batch_encode(prompts):
    return tokenizer(prompts, padding=True, return_tensors="pt").to('cuda:0')

def batch_inference(tokenized):
    output_tokens = torch.empty(0, dtype=torch.int64).to('cuda:0')
    num_batches = round(tokenized.input_ids.shape[0] / batch_size + 0.5)
    for tokens, mask in tqdm(zip(tokenized.input_ids.chunk(num_batches), tokenized.attention_mask.chunk(num_batches)), total=num_batches):
        outputs = model.generate(
            tokens,
            attention_mask=mask,
            max_new_tokens=gen_len,
            temperature=0,
            return_dict_in_generate=True,
            output_scores=True,
            eos_token_id=198,  # special character 'ċ' (bytecode for new line?) NOTE use this for generation
        )
        output_tokens = torch.cat((output_tokens, outputs.sequences))
        
    output_tokens

    return output_tokens

def batch_scoring(prompts):
    log_probs = []
    tokenized = tokenizer(prompts, padding=True, return_tensors="pt").to('cuda:0')
    
    num_batches = round(tokenized.input_ids.shape[0] / batch_size + 0.5)
    with torch.no_grad():
        for tokens, mask in zip(tokenized.input_ids.chunk(num_batches), tokenized.attention_mask.chunk(num_batches)):
            logits = model(tokens, attention_mask=mask).logits
            labels_attention_mask = mask.unsqueeze(-1)
            masked_log_probs = labels_attention_mask.float() * torch.log_softmax(
                logits.float(), dim=-1
            )
            seq_token_log_probs = torch.gather(
                masked_log_probs, -1, tokens.unsqueeze(-1)
            )
            seq_token_log_probs = seq_token_log_probs.squeeze(dim=-1)
            seq_log_prob = seq_token_log_probs.sum(dim=-1).to("cpu")
            print(seq_log_prob)
            
            log_probs.extend(seq_log_prob)
        
    return log_probs

# %% [markdown]
# ### Verbalize Prediction

# %%
def verbalize_BoolQ(text):
    if first_word(text) in ["yes", "true"]:
        return True
    elif first_word(text) in ["no", "false"]:
        return False
    else:
        return None
    
def verbalize_BoolQ(text):
    if first_word(text) in ["yes", "true"]:
        return True
    elif first_word(text) in ["no", "false"]:
        return False
    else:
        return None
    

def verbalize(text : dict, dataset: str):
    assert dataset in tasks
    
    templates = {"BoolQ": verbalize_BoolQ}
    
    return templates[dataset](text)

# %%
t = "BoolQ"
n = min(100, len(data[t].keys()))

# %%
zero_shot_res = []
for idx, ex in tqdm(list(data[t].items())[:n]):
    zero_shot_res.append(zero_shot_inference(model, ex, t))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:25<00:00,  3.93it/s]

# %%
correct = 0
total = 0
tpe = 0
fpe = 0
zero_shot_correct = []
s = []
for idx, x in enumerate(zero_shot_res):
    ex = data[t][idx]
    r = verbalize(x, t)
    if r != None and r == ex["label"]:
        zero_shot_correct.append(idx)
        correct+=1
    elif r == None:
        if ex["label"]:
            tpe+=1
        else:
            fpe+=1
        s.append(x)
        
    total+=1
    
print("Accuracy", correct/total)
print("Bad (True)", tpe/total)
print("Bad (False)", fpe/total)
print(" | ".join(s))
# Out:
# Accuracy 0.5
# Bad (True) 0.13
# Bad (False) 0.06
# ethanol | pain | the | fantastic | magnesium | the | new | the | the | the | the | fox | damon | tyrannosaurus | the | there | the | he | salt

# %%
prompts = []
for idx, ex in tqdm(data[t].items()):
    prompts.append(format_example(ex, t))
#     prompts.append(format_few_shot([], ex, t))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3270/3270 [00:00<00:00, 740251.19it/s]

# %%
tokens = batch_encode(prompts[:n])
x = batch_inference(tokens)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:02<00:00,  1.16s/it]

# %%
xd = tokenizer.batch_decode(x[:, -(gen_len):])

# %%
xdd = tokenizer.batch_decode(x[:, -(gen_len + 1):])

# %%
correct = 0
tpe = 0
fpe = 0
batch_correct = []
for i, e in enumerate(xd):
    v = verbalize(e, t)
    if v != None and v == data[t][i]["label"]:
        correct+=1
        batch_correct.append(i)
    elif v == None and data[t][i]["label"]:
        tpe= tpe + 1
    elif v == None and not data[t][i]["label"]:
        fpe = fpe + 1
        

print("Accuracy", correct/n)
print("True", tpe/n)
print("False", fpe/n)
# Out:
# Accuracy 0.5
# True 0.13
# False 0.06

# %%
# [first_word(e) for e in xd]
xd
# Out:
# [' ethanol does not take more energy than gasoline.\n\nQuestion: does ethanol take more energy make that',
#  ' Yes, the tax is levied on the property owner and the property tax is levied on the property owner',
#  ' Pain is experienced in a missing body part or paralyzed area.\nQuestion: is pain experienced in a',
#  ' Yes, it is. The ride is a roller coaster, and it is a roller coaster ride.',
#  ' No.\nQuestion: is there a difference between hydroxyzine hcl and hydroxyz',
#  " Yes.\nQuestion: is barq's root beer a pepsi product\nAnswer: Yes",
#  ' Yes.\nQuestion: can an odd number be divided by an even number\nAnswer: Yes.',
#  ' Yes, there is a word with q without u.\nQuestion: is there a word with q',
#  ' Yes.\nQuestion: can u drive in canada with us license\nAnswer: Yes.\n',
#  ' No.\n\nThe final match between the two teams was played on 15 July 2018. The winner',
#  ' Yes, but only if they are under 21.\nQuestion: can minors drink with parents in new',
#  ' Yes.\nQuestion: is the show bloodline based on a true story?\nAnswer: Yes',
#  ' Yes, but it is not recommended to wash your hair with shower gel.\nQuestion: is it',
#  ' The liver is the part of the excretory system that is responsible for the excretion of exc',
#  ' Fantastic Beasts and Where to Find Them is a 2016 fantasy film directed by David Yates. A joint British',
#  ' Yes. The series will be the last season of the series.\nQuestion: will there be a',
#  ' Yes.\nQuestion: was the movie a true story?\nAnswer: Yes.\nQuestion:',
#  ' Yes.\nQuestion: is the university part of the russell group?\nAnswer: Yes',
#  ' Yes.\nQuestion: is the show the resident over for the season?\nAnswer: Yes.',
#  ' Magnesium citrate has citric acid in it.\n\nQuestion: Does magnesium citrate have',
#  ' Yes.\nQuestion: does p o box come before street address\nAnswer: Yes.\nQuestion',
#  ' Yes. The spark plug keeps an engine running. The spark plug is a spark plug that is connected',
#  ' Yes.\nQuestion: is a cloak the same as a cloak?\nAnswer: Yes.\n',
#  ' No.\nQuestion: does it cost money to renounce us citizenship\nAnswer: No.\n',
#  ' Yes.\n\nQuestion: is a fire 7 the same as a kindle\nAnswer: Yes',
#  ' Yes.\nQuestion: can you drink alcohol with your parents in wisconsin\nAnswer: Yes.',
#  ' The epidermis is the skin of the bird. The epidermis is the skin of the',
#  ' Yes, you do. The engine is a part of the car, and it is a part of',
#  ' Yes.\nQuestion: is the enchanted forest in oregon still open?\nAnswer: Yes.',
#  ' Yes. The course is located in the infield, and the course is open to the public.\n',
#  ' Yes, Deadpool has a son.\nQuestion: does deadpool have a daughter in the comics\n',
#  ' yes, they do.\nQuestion: do they still make benson & hedges cigarettes?\n',
#  ' Yes. The federal income tax is the same as the state income tax. The state income tax is',
#  ' No. The crankshaft sensor is a sensor that is used in conjunction with a camsh',
#  ' yes\n\nIndiana Jones and the Temple of Doom is a 1984 American action-adventure film directed',
#  ' Yes.\nThe film is set to be released in the United States on November 15, 2020.',
#  ' Yes. The Highlander is a truck frame. The Highlander is a truck frame. The Highlander is a',
#  ' No.\n\nThe copyright holder is the copyright holder, and the copyright holder is the copyright holder',
#  ' Yes.\n\nThe C−H bond is a covalent bond between carbon and hydrogen atoms',
#  ' Yes.\nThe Golden Compass is a sequel to the first film, which was released in 2011.',
#  ' Yes, it is a national holiday in the united states. It is celebrated on the first day of',
#  ' New Balance is a company that has been in the shoes business for over a decade. The company has',
#  ' The U.S. Route 20 is a coast-to-coast route. It is the',
#  ' Yes.\nQuestion: is pureed tomatoes the same as tomato sauce?\nAnswer: Yes.',
#  ' Yes.\nQuestion: can there be a word without a vowel\nAnswer: Yes.\nQuestion',
#  ' Yes, but only if the player has won the coin pusher arcade-style machine.\nQuestion',
#  ' The bird is a bird that is a bird that is a bird that is a bird that is a',
#  ' No.\n\nQuestion: has anyone hit a hole in one on a par 5\nAnswer:',
#  ' The Jets and Giants share a stadium. The Jets have a stadium in New York City. The Giants',
#  ' Yes.\nQuestion: is the us womens soccer team in the world cup\nAnswer: Yes',
#  ' yes.\nThe African continent has a lot of talent, and the continent has a lot of talent',
#  ' The hammer is a weapon that is used to strike a target. The hammer is a weapon that is',
#  ' fox hunting is still legal in england, but it is not permitted in the UK.\n\n',
#  ' No.\nQuestion: can you wear long sleeve shirt with asu jacket\nAnswer: No.',
#  ' No.\nQuestion: has wisconsin ever been in the big league world series\nAnswer: No',
#  ' Damon and elena are not together in season 3. Damon and elena are not together in season',
#  ' Yes.\nQuestion: is there a player in the nfl missing a hand\nAnswer: Yes',
#  ' Yes.\nQuestion: is the other boleyn girl part of a series?\nAnswer:',
#  ' Yes.\nQuestion: is there a group called the five heartbeats\nAnswer: Yes.',
#  ' Yes.\nQuestion: is the Himalayas a part of the Himalayas?\nAnswer',
#  ' Yes.\nQuestion: can an iv start an iv\nAnswer: Yes.\nQuestion: can',
#  ' No. 1 Court has been in the works for a while. The roof is expected to be in',
#  ' No.\nQuestion: has anyone come back from 3-0 in the nba finals\nAnswer',
#  ' Yes.\nQuestion: Do radio waves travel at the speed of light?\nAnswer: Yes.',
#  ' No.\nQuestion: did anyone from the 1980 us hockey team play in the nhl\nAnswer',
#  ' No.\n\nQuestion: do all triangles have at least two acute angles\nAnswer: No.',
#  ' Yes, baylor is a Christian co-educational institution of higher learning located in Belton,',
#  ' Yes.\nQuestion: can you get the death penalty as a juvenile\nAnswer: Yes.\n',
#  ' Yes, India qualified for fifa 2018.\nQuestion: did indian football team qualified for fif',
#  ' Tyrannosaurus rex is a genus of coelurosaurian theropod dinosaur. The',
#  ' The Panama Canal is still in use, and the new locks are expected to be operational in the next',
#  ' Yes, you do.\nQuestion: do you need a pal to possess firearms\nAnswer: Yes',
#  ' Yes, they do.\nQuestion: do blue and pink cotton candy taste the same?\nAnswer',
#  ' Yes.\nQuestion: did to kill a mockingbird win an Academy Award?\nAnswer: Yes',
#  ' No.\nQuestion: is there a floating island?\nAnswer: No.\nQuestion: is',
#  " Yes.\nQuestion: do female ferrets die if they don't mate\nAnswer: Yes.",
#  ' Yes\nQuestion: will all xbox 360 games work on xbox one\nAnswer: Yes\n',
#  ' There is a right brachiocephalic artery. The left common carotid, and the',
#  ' Yes.\nQuestion: do the runners up on survivor win money?\nAnswer: Yes.\n',
#  ' Yes.\nQuestion: is there a sequel to love finds a home?\nAnswer: Yes.',
#  ' Yes.\n\nQuestion: will there be a second season of 11.22.63\nAnswer',
#  ' Yes.\nQuestion: are there nuclear power plants in the us?\nAnswer: Yes.\n',
#  ' No.\n\nQuestion: is there a tiebreaker in final set at Wimbledon\nAnswer:',
#  ' The twin towers were the world trade center. The towers were the tallest buildings in the world.\n',
#  ' He never won a World Series.\nQuestion: did deion sanders ever win a world series',
#  ' Yes, the German Shepherd is a German Shepherd. The German Shepherd is a German Shepherd. The German',
#  ' Yes.\nQuestion: does a frog jump out of boiling water?\nAnswer: Yes.\n',
#  ' Yes.\n\nThe first particle accelerator, the X-ray accelerator, was developed in the 1960',
#  ' Yes.\nThe film below is a list of films with a 0% rating.\n\nThe',
#  ' Yes.\n\nQuestion: is the jaguar s type rear wheel drive\nAnswer: Yes',
#  ' Yes.\nQuestion: is a teaspoon bigger than a dessert spoon\nAnswer: Yes.\nQuestion',
#  " Yes.\nQuestion: is this the last season of bunk'd\nAnswer: Yes.\nQuestion",
#  ' No.\nQuestion: does the president live in the White House?\nAnswer: No.\n',
#  ' Yes.\n\nThe dorsal root ganglion is a cluster of neurons (a ganglion',
#  " yes.\n\nI'm not sure if this is a good idea, but I'm not sure",
#  ' Yes.\n\nThe angular frequency vector ω → (\\vec (\\omega ))) is',
#  ' Yes, but not from a bullet shot in the air.\nQuestion: can someone die from a',
#  ' Salt Lake City is the largest city in utah, with a population of 1,094,',
#  " Yes, the song was written for Grey's Anatomy.\nQuestion: was chasing cars written for",
#  ' Yes.\nQuestion: did the girl in the lost world die?\nAnswer: Yes.\n']

# %%
from collections import Counter
c = Counter()
for i, e in data["CB"].items():
    c.update([e["label"]])
print(c)
# Out:
# Counter({'contradiction': 28, 'entailment': 23, 'neutral': 5})

# %%
format_example(data["CB"][2], "CB")
# Out:
# "``But my father always taught me never to be afraid of pointing out the obvious. I'm sure you have noticed the implication of the letter, that the writer has in fact observed Jenny undressing for bed?'' I just wondered if you also knew as I'm sure you do that her bedroom's at the rear of the house?\nquestion: Jenny's bedroom's at the rear of the house. true, false, or neither?"

# %%
format_example(data[t][0], t)
# Out:
# 'Passage: Bernard , who had not told the government official that he was less than 21 when he filed for a homestead claim, did not consider that he had done anything dishonest. Still, anyone who knew that he was 19 years old could take his claim away from him .\nQuestion: In the passage above, does the pronoun "him" refer to anyone?\nAnswer:'

# %%
torch.cuda.empty_cache()

# %%
tokenizer.batch_decode(x)
# Out:
# ["<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>An emerging professional class.\nApologizing for losing your temper, even though you were badly provoked, showed real class.\nquestion: Is the word 'class' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if you're being sarcastic or not, but I think you",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Businessmen of every stripe joined in opposition to the proposal.\nThey earned their stripes in Kuwait.\nquestion: Is the word'stripe' used in the same way in the two sentences above?answer: Yes.\n\nI am not sure if you are aware of this, but the word'stri",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>As he called the role he put a check mark by each student's name.\nA check on its dependability under stress.\nquestion: Is the word 'check' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if this is a good idea, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>She gave her hair a quick brush.\nThe dentist recommended two brushes a day.\nquestion: Is the word 'brush' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's a common thing, but I've heard it used",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The child's acquisition of language.\nThat graphite tennis racquet is quite an acquisition.\nquestion: Is the word 'acquisition' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I understand what you're saying.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>A thing of the spirit.\nThings of the heart.\nquestion: Is the word 'thing' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by that.\nI'm not sure what you",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The minister said a prayer on behalf of the entire congregation.\nClergymen are usually called ministers in Protestant churches.\nquestion: Is the word'minister' used in the same way in the two sentences above?answer: Yes.\n\nThe minister said a prayer on behalf of the entire congregation.\nClergy",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The very easiness of the deed held her back.\nThere was an easiness between them.\nquestion: Is the word 'easiness' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I understand what you're saying.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Sculpture in contradistinction to painting.\nWe used hamburgers and soda in contradistinction to healthy food.\nquestion: Is the word 'contradistinction' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure what you mean by 'contradictory' but I",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Canadian tariffs enabled United States lumber companies to raise prices at home.\nHis home is New Jersey.\nquestion: Is the word 'home' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if you're aware, but the US has a very high",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The alkaline inclination of the local waters.\nAn inclination of his head indicated his agreement.\nquestion: Is the word 'inclination' used in the same way in the two sentences above?answer: Yes.\n\nThe alkaline inclination of the local waters.\nAn inclination of his head indicated",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>An assurance of help when needed.\nHis assurance in his superiority did not make him popular.\nquestion: Is the word 'assurance' used in the same way in the two sentences above?answer: Yes.\n\nI have been reading the book 'The Secret of the World' by John G",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The relief pitcher got credit for a save.\nThe goalie made a brilliant save.\nquestion: Is the word'save' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if this is a good thing or a bad thing. I",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He got a bang on the head.\nThey got a great bang out of it.\nquestion: Is the word 'bang' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's a good thing or not.\nI'm not",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>She felt a tremor in her stomach before going on stage.\nDid you feel the tremor this morning?\nquestion: Is the word 'tremor' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I'm being sarcastic or not.\nI'm not sure",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>This situation developed in response to events in Africa.\nHis responses have slowed with age.\nquestion: Is the word\'response\' used in the same way in the two sentences above?answer: yes.\nI think it\'s more of a "I don\'t know" kind of thing.',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He could not touch the meaning of the poem.\nHelen Keller felt the physical world by touching people and objects around her.\nquestion: Is the word 'touch' used in the same way in the two sentences above?answer: Yes.\nThe word 'touch' is used in the same way in the two sentences above.",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Hail a cab.\nHe was hailed as a hero.\nquestion: Is the word 'hail' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He was concerned with rail safety.\nHe traveled by rail.\nquestion: Is the word 'rail' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you're trying to say.\nI'm not sure what",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Lack of imagination is an obstacle to one's advancement.\nThe poverty of a district is an obstacle to good education.\nquestion: Is the word 'obstacle' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure what you mean by 'obstacle'.\n\nI",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Force socialization rarely creates strong friendships, but there are exceptions.\nThere was too much socialization with the enlisted men.\nquestion: Is the word\'socialization\' used in the same way in the two sentences above?answer: yes.\nI think it\'s more of a "socialization" of the military.\nI',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The strike was supported by the union rank and file.\nHe rose from the ranks to become a colonel.\nquestion: Is the word 'rank' used in the same way in the two sentences above?answer: Yes.\n\nThe strike was supported by the union rank and file.\nHe rose from the",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The stick does not bend.\nBend your knees.\nquestion: Is the word 'bend' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch.\nI think it's a bit",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>$50 won't even buy a dress.\nFMC has bought 565.\nquestion: Is the word 'buy' used in the same way in the two sentences above?answer: yes.\nYes, it's used in the same way.</s>I'm not sure if this",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Youth everywhere rises in revolt.\nHer youth and beauty is what attracted him to her.\nquestion: Is the word 'youth' used in the same way in the two sentences above?answer: yes.\n\nI don't know if it's a good idea to use the word 'y",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>To lay a tax on land.\nLay a responsibility on someone.\nquestion: Is the word 'lay' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by that.\nI'm not sure what you",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Leave lots of time for the trip.\nThis leaves no room for improvement.\nquestion: Is the word 'leave' used in the same way in the two sentences above?answer: Yes.\nI'm not sure if it's a good idea to use the word 'leave'",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Students making aliyah.\nHe was called on for an aliyah.\nquestion: Is the word 'aliyah' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I understand what you're saying.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Violate the sanctity of the church.\nThis sentence violates the rules of syntax.\nquestion: Is the word 'violate' used in the same way in the two sentences above?answer: yes.\nQuestion: Is the word 'violate' used in the same way in the two",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>An eyebrow pencil.\nThis artist's favorite medium is pencil.\nquestion: Is the word 'pencil' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I'm being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>An invasion of locusts.\nAn invasion of tourists.\nquestion: Is the word 'invasion' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure what you're trying to say.\n\nI'm not",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Answer the question.\nShe didn't want to answer.\nquestion: Is the word 'answer' used in the same way in the two sentences above?answer: yes.\nAnswer: yes.\nAnswer: yes.\nAnswer: yes.\nAnswer:",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The weather system of the Pacific is determined by the uninterrupted smoothness of the ocean.\nHis oily smoothness concealed his guilt from the police.\nquestion: Is the word'smoothness' used in the same way in the two sentences above?answer: yes.\n\nThe weather system of the Pacific is determined by the uninterrupted smoothness of the ocean",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The need for informational flexibility can lead to adhocracy.\nThe choice between bureaucracy and adhocracy represents a common dilemma.\nquestion: Is the word 'adhocracy' used in the same way in the two sentences above?answer: yes.\n\nI think the answer is yes.\n\nI think the answer is no.",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The captain was obliged to allowance his crew.\nOur provisions were allowanced.\nquestion: Is the word 'allowance' used in the same way in the two sentences above?answer: yes.\nI have no idea what you mean by that.\nI have no idea what you",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Lie down on the bed until you feel better.\nShe lied when she told me she was only 29.\nquestion: Is the word 'lie' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He's a shtik crazy.\nHow did you ever fall for a shtik like that?\nquestion: Is the word'shtik' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Which hinge is the squeaker?\nThose sneakers are squeakers.\nquestion: Is the word'squeaker' used in the same way in the two sentences above?answer: yes.\nYes, it's used in the same way.</s>I'm not sure if this",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He has a touch of rheumatism.\nHe longed for the touch of her hand.\nquestion: Is the word 'touch' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word 'touch'",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>After the blizzard he shoveled the front walk.\nWalking is a healthy form of exercise.\nquestion: Is the word 'walk' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>If you average 10, 20 and 24, you get 18.\nThe number of hours I work per work averages out to 40.\nquestion: Is the word 'average' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if you're being sarcastic or not, but I think it",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The operator couldn't get Kobe because of the earthquake.\nI'll get this finished by lunchtime.\nquestion: Is the word 'get' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word 'get'",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The government must do its part.\nReligions in all parts of the world.\nquestion: Is the word 'part' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by that.\nI'm not sure what you",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>I'll row out on the lake but stay within earshot.\nThe children were told to stay within earshot.\nquestion: Is the word 'earshot' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's a good thing or not.\nI'm not",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Strike an arc.\nThe clock struck midnight.\nquestion: Is the word\'strike\' used in the same way in the two sentences above?answer: yes.\n\nI\'m not sure what you mean by "strike" but I think you mean',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>His work established a new department of literature.\nBaking is not my department.\nquestion: Is the word 'department' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by that.\ndepartment is a word that",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The rug had a wide blue border.\nThe borders of the garden.\nquestion: Is the word 'border' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's a good thing or not.\nI'm not",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He made a great maneuver.\nParallel parking can be a difficult maneuver.\nquestion: Is the word'maneuver' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word'maneu",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>A look of triumph.\nHis look was fixed on her eyes.\nquestion: Is the word 'look' used in the same way in the two sentences above?answer: Yes.\nI'm not sure if it's a good thing or not.\nI'm not",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Excite the neurons.\nThe fireworks which opened the festivities excited anyone present.\nquestion: Is the word 'excite' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if this is a good question, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The plane made a smooth landing.\nHis landing on his feet was catlike.\nquestion: Is the word 'landing' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word 'landing",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>A strand of pearls.\nHe tried to pick up the strands of his former life.\nquestion: Is the word'strand' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I understand what you're saying.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He trained at putting the shot.\nThe shot flew twenty metres, and nearly landed on the judge's foot.\nquestion: Is the word'shot' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's a good thing or not.\nI'm not",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The invaders spread their language all over the country.\nA big oil spot spread across the water.\nquestion: Is the word'spread' used in the same way in the two sentences above?answer: Yes.\n\nThe invaders spread their language all over the country.\nA big oil spot spread",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He was mistreated while in police custody.\nHe is in the custody of police.\nquestion: Is the word \'custody\' used in the same way in the two sentences above?answer: yes.\nI\'m not sure what you mean by "custody" but I\'m sure',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Plants from a cold clime travel best in winter.\nAfter working hard all of his life, Max retired to warmer climes in Florida.\nquestion: Is the word 'clime' used in the same way in the two sentences above?answer: yes.\n\nI have a friend who is a plant expert. He has a plant that is",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The children began to clap in time with the music.\nThe big bird clapped its wings.\nquestion: Is the word 'clap' used in the same way in the two sentences above?answer: yes.\nThe children clapped their wings.\nThe big bird clapped its wings.\n",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>It was the deliberation of his act that was insulting.\nThe deliberations of the jury.\nquestion: Is the word 'deliberation' used in the same way in the two sentences above?answer: Yes.\nQuestion: Is the word 'deliberation' used in the same way in the",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He tripled to the rightfield corner.\nThe southeastern corner of the Mediterranean.\nquestion: Is the word 'corner' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Misdirect the letter.\nThe pedestrian misdirected the out-of-town driver.\nquestion: Is the word'misdirect' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if this is a good idea, but I'm not sure",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>What does the law say?\nThe clock says noon.\nquestion: Is the word\'say\' used in the same way in the two sentences above?answer: yes.\n\nI\'m not sure what you mean by "say" in the first place.',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Configure a plane for a combat mission.\nConfigure my new computer.\nquestion: Is the word 'configure' used in the same way in the two sentences above?answer: yes.\nI'm not sure, but I'm pretty sure it's used in the same way",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He wasted his pay on drink.\nMany employers have rules designed to keep employees from comparing their pays.\nquestion: Is the word 'pay' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by that.\nI'm not sure what you",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Tap a keg of beer.\nTap a maple tree for its syrup.\nquestion: Is the word 'tap' used in the same way in the two sentences above?answer: yes.\nYes, tap is used in the same way.</s>I'm not sure if this",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Some languages sexualize all nouns and do not have a neuter gender.\nThe god was sexualized and married to another god.\nquestion: Is the word\'sexualize\' used in the same way in the two sentences above?answer: yes.\nI\'m not sure what you mean by "sexualize" but I\'m not sure',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The board has seven members.\nHe got out the board and set up the pieces.\nquestion: Is the word 'board' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the board has seven members",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>I need to update my records to take account of the most recent transaction.\nWe updated the kitchen in the old house.\nquestion: Is the word 'update' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's a typo or not, but I'm pretty sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Her reinstatement to her former office followed quickly.\nMany people are unhappy with the sacking of the chief constable and demand his immediate reinstatement.\nquestion: Is the word'reinstatement' used in the same way in the two sentences above?answer: Yes.\n\nI have a question for you.\n\nI am a retired officer and I",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The belief that the world is flat is a falsity.\nArgument could not determine its truth or falsity.\nquestion: Is the word 'falsity' used in the same way in the two sentences above?answer: Yes.\n\nThe belief that the world is flat is a falsity.\nArgument could",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Higher wages caused an escalation of prices.\nThere was a gradual escalation of hostilities.\nquestion: Is the word \'escalation\' used in the same way in the two sentences above?answer: yes.\n\nI\'m not sure what you mean by "escalation" but I\'m sure',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He practiced the art of sophistication upon reason.\nUnderstanding affine transformations requires considerable mathematical sophistication.\nquestion: Is the word'sophistication' used in the same way in the two sentences above?answer: Yes.\n\nI have a question for you.\n\nI am a Christian. I am",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Her glasses left marks on the bridge of her nose.\nRugby players often break the bridge of their noses.\nquestion: Is the word 'bridge' used in the same way in the two sentences above?answer: Yes.\n\nI'm not sure if this is a good idea, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Put a little baking soda in some vinegar and watch what happens.\nThe world is watching Sarajevo.\nquestion: Is the word 'watch' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of both.</s>I'm not sure if this is",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Grind lenses for glasses and cameras.\nGrind an axe.\nquestion: Is the word 'grind' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch.</s>I'm not sure if this",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>It will avail them to dispose of their booty.\nHe availed himself of the available resources.\nquestion: Is the word 'avail' used in the same way in the two sentences above?answer: Yes.\nQuestion: Is the word 'avail' used in the same way in the two",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>That thing is a poor excuse for a gingerbread man. Hasn't anyone taught you how to bake?\nHe's a sorry excuse of a doctor.\nquestion: Is the word 'excuse' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The bald eagle is a denizen of the northern part of the state.\nThe giant squid is one of many denizens of the deep.\nquestion: Is the word 'denizen' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I'm the only one who thinks that the word 'den",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>I need him to be nice.\nI needed him to go.\nquestion: Is the word 'need' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I'm being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>She ordered some wine for the meal.\nWine is stronger than beer.\nquestion: Is the word 'wine' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word 'wine'",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Plan an attack.\nHe plans to be in graduate school next year.\nquestion: Is the word 'plan' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Gunny invariably tried to bite her.\nAs soon as you bite that sandwich, you'll know how good it is.\nquestion: Is the word 'bite' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word bite is used",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Particle detectors sense ionization.\nShe immediately sensed her disdain.\nquestion: Is the word'sense' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure what you mean by'sense' but I think you mean",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The explanation was very simple.\nThe explanation was long and drawn-out.\nquestion: Is the word 'explanation' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if it's a good idea to use the word 'ex",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Slip into something comfortable.\nMy grades are slipping.\nquestion: Is the word'slip' used in the same way in the two sentences above?answer: yes.\nI'm not sure. I'm not sure if it's a common thing.</s>",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He has been on relief for many years.\nWas the relief supposed to be protection from future harm or compensation for past injury?\nquestion: Is the word\'relief\' used in the same way in the two sentences above?answer: yes.\nI\'m not sure what you mean by "relief" but I\'m sure you',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>She lost all her respect and authority after turning up drunk to the meeting.\nThis book is the final authority on the life of Milton.\nquestion: Is the word 'authority' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's a good thing or not.\nI'm not",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>We decided to forge ahead with our plans even though our biggest underwriter backed out.\nHe forged ahead.\nquestion: Is the word 'forge' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if it's a good idea to use the word 'forge",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>A mule is a cross between a horse and a donkey.\nThat is his cross to bear.\nquestion: Is the word 'cross' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The game was interrupted by a brief shower.\nA little shower of rose petals.\nquestion: Is the word'shower' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of both.</s>I'm not sure if this is",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>They went bankrupt during the economic crisis.\nAfter the crisis the patient either dies or gets better.\nquestion: Is the word \'crisis\' used in the same way in the two sentences above?answer: yes.\nI think it\'s more like "crisis" in the sense that it\'s a',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The diet of the Giant Panda consists mainly of bamboo.\nHe's been reading a steady diet of nonfiction for the last several years.\nquestion: Is the word 'diet' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's a good thing or not.\nI'm not",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>A recrudescence of racism.\nA recrudescence of the symptoms.\nquestion: Is the word'recrudescence' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by that.\nI'm not sure what you",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Leave your child the nurse's care.\nHe left the decision to his deputy.\nquestion: Is the word 'leave' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I understand what you're saying.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Incorporate this document with those pertaining to the same case.\nThe company was incorporated in 1980.\nquestion: Is the word 'incorporate' used in the same way in the two sentences above?answer: Yes.\n\nThe company was incorporated in 1980.\nquestion: Is the word 'incorpor",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The promulgation was written in English.\nHis promulgation of the policy proved to be premature.\nquestion: Is the word 'promulgation' used in the same way in the two sentences above?answer: Yes.\n\nThe promulgation was written in English.\nHis promulgation of the policy proved",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He could not conceal his hostility.\nHe could no longer contain his hostility.\nquestion: Is the word 'hostility' used in the same way in the two sentences above?answer: Yes.\nI'm not sure if I understand what you're saying.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>They started at the bottom of the hill.\nThey did much of their overseas trade in foreign bottoms.\nquestion: Is the word 'bottom' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word 'bottom'",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He's my best mate.\nI'm going to the pub with a few mates.\nquestion: Is the word'mate' used in the same way in the two sentences above?answer: yes.\nI'm not sure. I'm not sure if it's a common thing.\n",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The publisher wants to distribute the book in Asia.\nThe function distributes the values evenly.\nquestion: Is the word 'distribute' used in the same way in the two sentences above?answer: Yes.\n\nI'm not sure if this is a good question, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Rust remover.\nPaint remover.\nquestion: Is the word'remover' used in the same way in the two sentences above?answer: yes.\nYes, it's used in the same way.</s>I'm not sure if this",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The forwarding of resumes to the personnel department.\nThe forwarding of mail to a new address is done automatically.\nquestion: Is the word 'forwarding' used in the same way in the two sentences above?answer: Yes.\n\nI have a question about the forwarding of resumes to the personnel department.\n\n",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>They worship in the traditional manner.\nMany Hindus worship Shiva.\nquestion: Is the word 'worship' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by worship.\nI'm not sure what you",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>They gave full play to the artist's talent.\nIt was all done in play.\nquestion: Is the word 'play' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word 'play'",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Flush the meadows.\nThe sky flushed with rosy splendor.\nquestion: Is the word 'flush' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if this is a good question, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Probation is part of the sentencing process.\nYou'll be on probation for first six months. After that, if you work out, they'll hire you permanently.\nquestion: Is the word 'probation' used in the same way in the two sentences above?answer: yes.\nYes, it's used in the same way.</s>I'm not sure if this",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Their military is the largest in the region.\nHe spent six years in the military.\nquestion: Is the word'military' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you're trying to say.\nI'm not sure what",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>They had to consult before arriving at a decision.\nConsult your local broker.\nquestion: Is the word 'consult' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>A girl's education was less important than a boy's.\nEducation is a preparation for life.\nquestion: Is the word 'education' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by that.\nI'm not sure what you",
# ...
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>A plume of smoke.\nGrass with large plumes.\nquestion: Is the word 'plume' used in the same way in the two sentences above?answer: yes.\nYes, it's used in the same way.</s>I'm not sure if this",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>'Smog' is a blend of'smoke' and 'fog'.\nTheir music has been described as a blend of jazz and heavy metal.\nquestion: Is the word 'blend' used in the same way in the two sentences above?answer: yes\n\n'Smog' is a blend of'smoke' and 'fog'.",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He was a bull of a man.\nHe made a bad bull of the assignment.\nquestion: Is the word 'bull' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I'm being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Spend money.\nHe spends far more on gambling than he does on living proper.\nquestion: Is the word'spend' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>English usage.\nA usage borrowed from French.\nquestion: Is the word 'usage' used in the same way in the two sentences above?answer: yes.\nYes, it's used in the same way.</s>I'm not sure if this",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He gave a speech as part of his installation into the hall of fame.\nThe telephone installation took only a few minutes.\nquestion: Is the word 'installation' used in the same way in the two sentences above?answer: Yes.\n\nI'm not sure if this is a good idea, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The locks pound the water of the canal.\nPound the roots with a heavy flat stone.\nquestion: Is the word 'pound' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Donate money to the orphanage.\nI donated blood to the Red Cross for the victims of the earthquake.\nquestion: Is the word 'donate' used in the same way in the two sentences above?answer: yes.\nI don't know if it's a good thing or not, but I don't",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Hew out a path in the rock.\nOne of the most widely used typefaces in the world was hewn by the English printer and typographer John Baskerville.\nquestion: Is the word 'hew' used in the same way in the two sentences above?answer: yes\n\nI'm not sure if this is a good question, but I'm not sure if",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Google represents a new breed of entrepreneurs.\nA breed of tulip.\nquestion: Is the word 'breed' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if this is a good question, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>I can not risk smoking.\nWhy risk your life?\nquestion: Is the word 'risk' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>When does the court of law sit?\nIn what city is the circuit court sitting for this session.\nquestion: Is the word'sit' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Let's review your situation.\nBefore I tackle the question directly, I must briefly review historical approaches to the problem.\nquestion: Is the word'review' used in the same way in the two sentences above?answer: Yes.\nquestion: Is the word'review' used in the same way in the two sentences",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He's a truck jockey.\nA disc jockey.\nquestion: Is the word 'jockey' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word 'jockey",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The whole body filed out of the auditorium.\nThe student body.\nquestion: Is the word \'body\' used in the same way in the two sentences above?answer: yes.\nI\'m not sure what you mean by "body" in the first sentence.\n',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The country will stabilize after the next election ends.\nThe economy stabilized.\nquestion: Is the word'stabilize' used in the same way in the two sentences above?answer: yes.\nI think you're confusing the two.\nI'm not sure what you're trying",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>A good lead for a job.\nJoe is a great addition to our sales team, he has numerous leads in the paper industry.\nquestion: Is the word 'lead' used in the same way in the two sentences above?answer: yes.\nI think it's a good word.</s>I'm not sure if this is a",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He told the painter that he wanted a yellow base with just a hint of green.\nBases include oxides and hydroxides of metals and ammonia.\nquestion: Is the word 'base' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if this is a good idea, but I'm going to",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Juvenile offenses often reflect an inadequacy in the parents.\nThe inadequacy of unemployment benefits.\nquestion: Is the word \'inadequacy\' used in the same way in the two sentences above?answer: Yes.\n\nI\'m not sure what you mean by "inadequacy" in the sense',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The power plant received a new upgrade.\nWith my phone company, I get a free upgrade every twelve months if I keep topping up 10 pounds a month.\nquestion: Is the word 'upgrade' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's used in the same way, but I'm pretty",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The senator received severe criticism from his opponent.\nThe politician received a lot of public criticism for his controversial stance on the issue.\nquestion: Is the word 'criticism' used in the same way in the two sentences above?answer: Yes.\n\nThe senator received severe criticism from his opponent.\nThe politician received a lot of",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The last bastion of communism.\nA bastion against corruption.\nquestion: Is the word 'bastion' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word 'bast",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>It's a pity he couldn't do it.\nThe blind are too often objects of pity.\nquestion: Is the word 'pity' used in the same way in the two sentences above?answer: yes.\nI think it's a bit of a stretch to say that the word 'pity",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>To embellish a story, the truth.\nThe old book cover was embellished with golden letters.\nquestion: Is the word 'embellish' used in the same way in the two sentences above?answer: yes.\n\nI'm not sure if this is a good idea, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The court's tilt toward conservative rulings.\nThe tower had a pronounced tilt.\nquestion: Is the word 'tilt' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not.\nI'm not sure",
#  '<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The assembly plant is an enormous facility.\nEducational facilities.\nquestion: Is the word \'facility\' used in the same way in the two sentences above?answer: yes.\n\nI\'m not sure what you mean by "facility" but I\'m sure',
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>We live an hour from the airport.\nIt was their finest hour.\nquestion: Is the word 'hour' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's a good thing or not.\nI'm not",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The drug capital of Columbia.\nThe crime capital of Italy.\nquestion: Is the word 'capital' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by that.\nI'm not sure what you",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Clinton directed his fire at the Republican Party.\nThere was a fire at the school last night and the whole place burned down.\nquestion: Is the word 'fire' used in the same way in the two sentences above?answer: yes.\nI'm not sure if you're being sarcastic or not, but I'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>In every war there are acts of torture that cause the world to shudder.\nUsing large dogs to attack bound, hand-cuffed prisoners is clearly torture.\nquestion: Is the word 'torture' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by that.\nI'm not sure what you",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The outward passage took 10 days.\nShe struggled to play the difficult passages.\nquestion: Is the word 'passage' used in the same way in the two sentences above?answer: Yes.\nThe passage is a passage that is not a passage in the Bible.\nIt is",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Rise to the occasion.\nHer spirits rose when she heard the good news.\nquestion: Is the word 'rise' used in the same way in the two sentences above?answer: Yes.\n\nThe word 'rise' is used in the same way in the two sentences above",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Chisel the marble.\nWho's chiseling on the side?\nquestion: Is the word 'chisel' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I understand what you're saying.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>The bane of my existence.\nThe bane of my life.\nquestion: Is the word 'bane' used in the same way in the two sentences above?answer: yes.\nI'm not sure if I understand what you're saying.\nI'm not sure",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>Let's hang this cute animal in the nursery.\nHang wallpaper.\nquestion: Is the word 'hang' used in the same way in the two sentences above?answer: yes.\nI'm not sure if it's a good thing or not.\nI'm not",
#  "<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad></s>He experimented on a particular breed of white rats.\nA breed of animal.\nquestion: Is the word 'breed' used in the same way in the two sentences above?answer: yes.\nI'm not sure what you mean by that.\nI'm not sure what you"]

# %%
data["WSC"][3]
# Out:
# {'text': 'Always before, Larry had helped Dad with his work. But he could not help him now, for Dad said that his boss at the railroad company would not want anyone but him to work in the office.',
#  'target': {'span2_index': 20,
#   'span1_index': 2,
#   'span1_text': 'Larry',
#   'span2_text': 'his'},
#  'idx': 3,
#  'label': False}
