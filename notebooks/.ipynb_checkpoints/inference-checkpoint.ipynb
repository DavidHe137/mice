# %% [markdown]
# ## Model Loading
# ### Memory & Time

# %%
# %%time
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
def mem_info(func):
    def wrapper(*args, **kw):
        pre = torch.cuda.mem_get_info()[0] / (10**9)
        func(*args, **kw)
        post = torch.cuda.mem_get_info()[0] / (10**9)
        print("Memory used:", pre - post)
    return wrapper

models = {"opt-125m": "facebook/opt-125m",
          "opt-350m": "facebook/opt-350m",
          "opt-1.3b": "facebook/opt-1.3B",
          "opt-2.7b": "facebook/opt-2.7B",
          "opt-6.7b": "facebook/opt-6.7B"}

@mem_info
def load_model(model_dict, model):
    # %time model_dict[model] = AutoModelForCausalLM.from_pretrained(models[model], ).cuda()
# Out:
# CPU times: user 1.12 s, sys: 321 ms, total: 1.45 s
# Wall time: 33.5 s

# %%
loaded = {}
# load_model(loaded, "opt-125m")

# %%
load_model(loaded, "opt-350m")

# %%
load_model(loaded, "opt-1.3b")
# Out:
# CPU times: user 7.67 s, sys: 2.26 s, total: 9.92 s
# Wall time: 8.66 s
# Memory used: 5.268045823999998

# %%
load_model(loaded, "opt-2.7b")
# Out:
# CPU times: user 21.1 s, sys: 7.68 s, total: 28.8 s
# Wall time: 25.4 s
# Memory used: 10.745806848

# %%
load_model(loaded, "opt-6.7b")

# %%
torch.cuda.empty_cache()

# %%
torch.cuda.mem_get_info()[0] / (10**9)
# Out:
# 6.653673472

# %% [markdown]
# ## Individual vs Batch Encoding

# %%
# %%time
print(torch.cuda.mem_get_info()[0] / (10**9))
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-125m", use_fast=False, padding_side='left',)
print(torch.cuda.mem_get_info()[0] / (10**9))
# Out:
# 24.79194112
# 24.79194112
# CPU times: user 77.4 ms, sys: 13 ms, total: 90.4 ms
# Wall time: 2.25 s

# %%
model = loaded["opt-350m"]
sentence1 = "I like cheese"
sentence2 = "I really like cheese. I also really like sandwiches."
sentences = [sentence1, sentence2 ] * 100

# %%
# %%time
print(torch.cuda.mem_get_info()[0] / (10**9))
batch_tokens = tokenizer(sentences, padding=True, return_tensors="pt").to('cuda:0')
print(torch.cuda.mem_get_info()[0] / (10**9))
# Out:
# 20.485308416
# 20.485308416
# CPU times: user 14.2 ms, sys: 1.15 ms, total: 15.4 ms
# Wall time: 14.5 ms

# %%
# %%time
print(torch.cuda.mem_get_info()[0] / (10**9))
outputs = model.generate(
    batch_tokens['input_ids'],
    max_new_tokens=5,
    temperature=0,
    return_dict_in_generate=True,
    output_scores=True,
    eos_token_id=198,  # special character 'ċ' (bytecode for new line?) NOTE use this for generation
)
print(torch.cuda.mem_get_info()[0] / (10**9))
# Out:
# 20.485308416
# 9.116647424
# CPU times: user 1.86 s, sys: 1.4 s, total: 3.26 s
# Wall time: 3.27 s

# %%
# %%time
print(torch.cuda.mem_get_info()[0] / (10**9))
tokens = [tokenizer(x, return_tensors="pt").to('cuda:0') for x in sentences]
print(torch.cuda.mem_get_info()[0] / (10**9))
# Out:
# 8.802074624
# 8.802074624
# CPU times: user 32.1 ms, sys: 0 ns, total: 32.1 ms
# Wall time: 31.6 ms

# %% [markdown]
# ## Individual vs Batch Inference

# %%
# %%time
print(torch.cuda.mem_get_info()[0] / (10**9))
looped = []
for x in tokens:
    looped.append(model.generate(
        x['input_ids'],
        max_new_tokens=5,
        temperature=0,
        return_dict_in_generate=True,
        output_scores=True,
        eos_token_id=198,  # special character 'ċ' (bytecode for new line?) NOTE use this for generation
    ))
print(torch.cuda.mem_get_info()[0] / (10**9))
# Out:
# 9.116647424
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# tensor([[   2,  100,  101, 7134]], device='cuda:0')
# tensor([[    2,   100,   269,   101,  7134,     4,    38,    67,   269,   101,
#          19072,     4]], device='cuda:0')
# 8.802074624
# CPU times: user 33.9 s, sys: 15.7 s, total: 49.5 s
# Wall time: 49.4 s

# %%
outputs.sequences[:]
# Out:
# tensor([[   1,    1,    1,  ...,  100,  101, 7134],
#         [   2,  100,  269,  ...,  101, 7134,  350],
#         [   1,    1,    1,  ...,  100,  101, 7134],
#         ...,
#         [   2,  100,  269,  ...,  101, 7134,  350],
#         [   1,    1,    1,  ...,  100,  101, 7134],
#         [   2,  100,  269,  ...,  101, 7134,  350]], device='cuda:0')

# %%
# %%time
print(torch.cuda.mem_get_info()[0] / (10**9))
z = tokenizer.batch_decode(outputs.sequences[:])
print(torch.cuda.mem_get_info()[0] / (10**9))
print(z)
# Out:
# 8.802074624
# 8.802074624
ad><pad><pad><pad><pad><pad></s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '<pad><pad><pad><pad><pad><pad><pad><pad></s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '<pad><pad><pad><pad><pad><pad><pad><pad></s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '<pad><pad><pad><pad><pad><pad><pad><pad></s>I like cheese.\nI like cheese', '</s>I really like che ...
# CPU times: user 8.66 ms, sys: 323 µs, total: 8.98 ms
# Wall time: 8.19 ms

# %%
# %%time
print(torch.cuda.mem_get_info()[0] / (10**9))
y = []
for x in looped:
    y.append(tokenizer.decode(x.sequences[0]))
print(torch.cuda.mem_get_info()[0] / (10**9))
print(y)
# Out:
# 8.802074624
# 8.802074624
# ['</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like cheese. I also really like sandwiches.\nI like cheese too', '</s>I like cheese.\nI like cheese', '</s>I really like ...
# CPU times: user 5.85 ms, sys: 2.91 ms, total: 8.76 ms
# Wall time: 8.08 ms

# %%
torch.tensor(torch.cuda.mem_get_info()) / 10**9
# Out:
# tensor([46.1775, 47.8508])

# %%
batch_tokens['input_ids']
# Out:
# tensor([[    1,     1,     1,  ...,   100,   101,  7134],
#         [    2,   100,   269,  ...,   101, 19072,     4],
#         [    1,     1,     1,  ...,   100,   101,  7134],
#         ...,
#         [    2,   100,   269,  ...,   101, 19072,     4],
#         [    1,     1,     1,  ...,   100,   101,  7134],
#         [    2,   100,   269,  ...,   101, 19072,     4]], device='cuda:0')

# %%
tokenizer.batch_decode(outputs.sequences[:, -5:])
# Out:
# ['.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too',
#  '.\nI like cheese',
#  '\nI like cheese too']

# %% [markdown]
# ## Testing

# %%
import os
import json
import torch
import sys
import gc
import time

def read_json(filepath: str) -> dict:
    with open(filepath, "r") as f:
        return json.load(f)
    
def read_jsonl(filepath: str) -> dict:
    data = []
    with open(filepath, "r") as f:
        for line in f.readlines():
            example = json.loads(line)
            data.append(example)
    return data

def format_example(example : dict, dataset: str, includeLabel=False) -> str:
    superGLUE = ['BoolQ', 'COPA', 'RTE', 'WiC', 'WSC']
    assert dataset in superGLUE

    templates = {
        'BoolQ' : lambda ex: f"Passage: {ex['passage']}\nQuestion: {ex['question']}\nAnswer:",
        'COPA' : lambda ex: f"Premise: {ex['premise']}\nQuestion: What's the {ex['question']} of this?\nAlternative 1: {ex['choice1']}\nAlternative 2: {ex['choice2']}\nCorrect Alternative:",
        'WSC' : lambda ex: f"Text: {ex['text']}\nQuestion: Does {ex['target']['span2_text']} refer to {ex['target']['span1_text']}?\nAnswer:", 
        'WiC' : lambda ex: f"Context 1: {ex['sentence1']}\nContext 2: {ex['sentence2']}\nWord: {ex['word']}\nSense Match:", 
        'RTE' : lambda ex: f"Text: {ex['premise']}\nHypothesis: {ex['hypothesis']}\nEntailment:"
    }
    

    text = templates[dataset](example)

    if includeLabel:
        if dataset == 'COPA':
            text += f"{example['label'] + 1}\n" #NOTE: COPA labeling is weird
        else:
            text += f"{example['label']}\n"

    return text

def create_model_input_text(
    test_example, train_examples, dataset, tokenizer
):
    #TODO: worry about input len at some point
    demonstrations = ''.join(list(map(lambda x: format_example(x, dataset, includeLabel=True), train_examples)))
    test_input = format_example(test_example, dataset)

    input_text = demonstrations + test_input

    return input_text

def mem_info():
    print("Free(GB):", torch.cuda.mem_get_info()[0] / (10**9))

# %%
mem_info()
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-125m", use_fast=False, padding_side='left',)
model = AutoModelForCausalLM.from_pretrained("facebook/opt-1.3b").cuda()
mem_info()
# Out:
# Free(GB): 47.12333312
# Free(GB): 36.377526272

# %%
exp = os.path.join("..", "old_experiments", "BoolQ", "id_1_train_16_test_64")
train = read_jsonl(os.path.join(exp, "train.jsonl"))
train = {x['idx']: x for x in train}
test = read_jsonl(os.path.join(exp, "test.jsonl"))
test = {x['idx']: x for x in test}
prompt_map = read_json(os.path.join(exp, "generations", "similar_2_64_all-roberta-large-v1","prompt_map.json"))

# %%
print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |   10243 MB |   10243 MB |   10243 MB |       0 B  |
# |       from large pool |   10238 MB |   10238 MB |   10238 MB |       0 B  |
# |       from small pool |       4 MB |       4 MB |       4 MB |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |   10243 MB |   10243 MB |   10243 MB |       0 B  |
# |       from large pool |   10238 MB |   10238 MB |   10238 MB |       0 B  |
# |       from small pool |       4 MB |       4 MB |       4 MB |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |   10248 MB |   10248 MB |   10248 MB |       0 B  |
# |       from large pool |   10242 MB |   10242 MB |   10242 MB |       0 B  |
# |       from small pool |       6 MB |       6 MB |       6 MB |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |    5080 KB |    5170 KB |    9200 KB |    4120 KB |
# |       from large pool |    3116 KB |    3116 KB |    3116 KB |       0 KB |
# |       from small pool |    1964 KB |    2054 KB |    6084 KB |    4120 KB |
# |---------------------------------------------------------------------------|
# | Allocations           |     516    |     516    |     516    |       0    |
# |       from large pool |     194    |     194    |     194    |       0    |
# |       from small pool |     322    |     322    |     322    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |     516    |     516    |     516    |       0    |
# |       from large pool |     194    |     194    |     194    |       0    |
# |       from small pool |     322    |     322    |     322    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |     197    |     197    |     197    |       0    |
# |       from large pool |     194    |     194    |     194    |       0    |
# |       from small pool |       3    |       3    |       3    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       5    |       5    |       5    |       0    |
# |       from large pool |       2    |       2    |       2    |       0    |
# |       from small pool |       3    |       3    |       3    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
# %%time
for k in range(64):
    print("Example", k)
    pre = torch.cuda.mem_get_info()[0] / (10**9)
    outputs['22'].append(model.generate(
        batch_tokens['22']['input_ids'][k][None, :],
        max_new_tokens=5,
        temperature=0,
        return_dict_in_generate=True,
        output_scores=True,
        eos_token_id=198,  # special character 'ċ' (bytecode for new line?) NOTE use this for generation
    ))
    post = torch.cuda.mem_get_info()[0] / (10**9)
    print("Used: ", pre - post, "\n")
# Out:
# Example 0
# Used:  1.0003415039999979
#
# Example 1
# Used:  0.11324620799999963
#
# Example 2
# Used:  0.11114905600000213
#
# Example 3
# Used:  0.11114905600000213
#
# Example 4
# Used:  0.11324620799999963
#
# Example 5
# Used:  0.11114905600000213
#
# Example 6
# Used:  0.11324620799999963
#
# Example 7
# Used:  0.11114905599999503
#
# Example 8
# Used:  0.11114905600000213
#
# Example 9
# Used:  0.11324620799999963
#
# Example 10
# Used:  0.11114905600000213
#
# Example 11
# Used:  0.11324620799999963
#
# Example 12
# Used:  0.11114905599999503
#
# Example 13
# Used:  0.11114905600000213
#
# Example 14
# Used:  0.11324620799999963
#
# Example 15
# Used:  0.11114905600000213
#
# Example 16
# Used:  0.11324620799999963
#
# Example 17
# Used:  0.11114905600000213
#
# Example 18
# Used:  0.11114905599999503
#
# Example 19
# Used:  0.11324620799999963
#
# Example 20
# Used:  0.11114905600000213
#
# Example 21
# Used:  0.11324620799999963
#
# Example 22
# Used:  0.11114905600000213
#
# Example 23
# Used:  0.11114905600000213
#
# Example 24
# Used:  0.11324620799999963
#
# Example 25
# Used:  0.11114905599999503
#
# Example 26
# Used:  0.11324620799999963
#
# Example 27
# Used:  0.11114905600000213
#
# Example 28
# Used:  0.11114905600000213
#
# Example 29
# Used:  0.11324620799999963
#
# Example 30
# Used:  0.11114905600000213
#
# Example 31
# Used:  0.11324620799999963
#
# Example 32
# Used:  0.11114905599999503
#
# Example 33
# Used:  0.11114905600000213
#
# Example 34
# Used:  0.11324620799999963
#
# Example 35
# Used:  0.11114905600000213
#
# Example 36
# Used:  0.11324620799999963
#
# Example 37
# Used:  0.11114905600000213
#
# Example 38
# Used:  0.11114905599999503
#
# Example 39
# Used:  0.11324620799999963
#
# Example 40
# Used:  0.11114905600000213
#
# Example 41
# Used:  0.11324620799999963
#
# Example 42
# Used:  0.11114905600000213
#
# Example 43
# Used:  0.11114905599999503
#
# Example 44
# Used:  0.11324620799999963
#
# Example 45
# Used:  0.11114905600000213
#
# Example 46
# Used:  0.11324620799999963
#
# Example 47
# Used:  0.11114905600000213
#
# Example 48
# Used:  0.11114905600000213
#
# Example 49
# Used:  0.11324620799999963
#
# Example 50
# Used:  0.11114905599999503
#
# Example 51
# Used:  0.11324620799999963
#
# Example 52
# Used:  0.11114905600000213
#
# Example 53
# Used:  0.11114905600000213
#
# Example 54
# Used:  0.11324620799999963
#
# Example 55
# Used:  0.11114905600000213
#
# Example 56
# Used:  0.11324620799999963
#
# Example 57
# Used:  0.11114905599999503
#
# Example 58
# Used:  0.11114905600000213
#
# Example 59
# Used:  0.11324620799999963
#
# Example 60
# Used:  0.11114905600000213
#
# Example 61
# Used:  0.11324620799999963
#
# Example 62
# Used:  0.11114905600000213
#
# Example 63
# Used:  0.11114905599999503
#
# CPU times: user 9.92 s, sys: 2.51 s, total: 12.4 s
# Wall time: 10.3 s

# %%
for k, v in list(prompt_map.items())[:1]:
    print(k)
    t = [tuple(x) for x in v]
    print(t)
# Out:
# 22
# [(2342, 2342), (2342, 3554), (2342, 6094), (2342, 7165), (2342, 9199), (2342, 453), (2342, 6114), (2342, 7378), (3554, 2342), (3554, 3554), (3554, 6094), (3554, 7165), (3554, 9199), (3554, 453), (3554, 6114), (3554, 7378), (6094, 2342), (6094, 3554), (6094, 6094), (6094, 7165), (6094, 9199), (6094, 453), (6094, 6114), (6094, 7378), (7165, 2342), (7165, 3554), (7165, 6094), (7165, 7165), (7165, 9199), (7165, 453), (7165, 6114), (7165, 7378), (9199, 2342), (9199, 3554), (9199, 6094), (9199, 7165), (9199, 9199), (9199, 453), (9199, 6114), (9199, 7378), (453, 2342), (453, 3554), (453, 6094), (453, 7165), (453, 9199), (453, 453), (453, 6114), (453, 7378), (6114, 2342), (6114, 3554), (6114, 6094), (6114, 7165), (6114, 9199), (6114, 453), (6114, 6114), (6114, 7378), (7378, 2342), (7378, 3554), (7378, 6094), (7378, 7165), (7378, 9199), (7378, 453), (7378, 6114), (7378, 7378)]

# %%
# %%time
max_generated_len = 3
results = {}
mem_info()
for test_id, prompt_ids in prompt_map.items(): 
    print("Example", test_id)
    
    train_ids = [tuple(ids) for ids in prompt_ids] 
    preds = []
    
    test_text = test[int(test_id)]
    input_text = [create_model_input_text(test_text, [train[int(z)] for z in a], 'BoolQ', tokenizer) for a in prompt_ids]
    batch_tokens = tokenizer(input_text, padding=True, return_tensors="pt").to('cuda:0')

    batch_size = 16
    num_batches = int(batch_tokens['input_ids'].shape[0] / batch_size)
    for batch in batch_tokens['input_ids'].chunk(num_batches):
        outputs = model.generate(
            batch,
            max_new_tokens=max_generated_len,
            temperature=0,
            return_dict_in_generate=True,
            output_scores=True,
            eos_token_id=198,  # special character 'ċ' (bytecode for new line?) NOTE use this for generation
        )

        preds.extend(tokenizer.batch_decode(outputs.sequences[:, -max_generated_len:]))

        mem_info()
    
    results[test_id] = {x[0]: x[1] for x in zip(train_ids, preds)}
    print(results[test_id])
# Out:
# Free(GB): 22.368550912
# Example 22
# Free(GB): 12.98169856
# Free(GB): 11.207507968
# Free(GB): 11.207507968
# Free(GB): 11.207507968
# {(2342, 2342): 'False\nPass', (2342, 3554): 'False\nPass', (2342, 6094): 'False\nPass', (2342, 7165): 'False\nPass', (2342, 9199): 'False\nPass', (2342, 453): 'False\nPass', (2342, 6114): 'False\nPass', (2342, 7378): 'False\nPass', (3554, 2342): 'True\nPass', (3554, 3554): 'True\nPass', (3554, 6094): 'False\nPass', (3554, 7165): 'True\nPass', (3554, 9199): 'True\nPass', (3554, 453): 'True\nPass', (3554, 6114): 'True\nPass', (3554, 7378): 'False\nPass', (6094, 2342): 'False\nPass', (6094, 3554): 'False\nPass', (6094, 6094): 'False\nPass', (6094, 7165): 'False\nPass', (6094, 9199): 'False\nPass', (6094, 453): 'False\nPass', (6094, 6114): 'False\nPass', (6094, 7378): 'False\nPass', (7165, 2342): 'False\nPass', (7165, 3554): 'True\nPass', (7165, 6094): 'False\nPass', (7165, 7165): ' True\nPass', (7165, 9199): 'False\nPass', (7165, 453): 'False\nPass', (7165, 6114): 'False\nPass', (7165, 7378): 'True\nPass', (9199, 2342): 'False\nPass', (9199, 3554): 'False\nPass', (9199, 6094): 'False\nPass', (9199, 7165): 'False\nPass', (9199, 9199): 'False\nPass', (9199, 453): 'False\nPass', (9199, 6114): 'False\nPass', (9199, 7378): 'False\nPass', (453, 2342): 'False\nPass', (453, 3554): 'False\nPass', (453, 6094): 'False\nPass', (453, 7165): 'False\nPass', (453, 9199): 'False\nPass', (453, 453): 'False\nPass', (453, 6114): 'False\nPass', (453, 7378): 'False\nPass', (6114, 2342): 'False\nPass', (6114, 3554): 'False\nPass', (6114, 6094): 'False\nPass', (6114, 7165): 'False\nPass', (6114, 9199): 'False\nPass', (6114, 453): 'False\nPass', (6114, 6114): 'False\nPass', (6114, 7378): 'False\nPass', (7378, 2342): 'True\nPass', (7378, 3554): 'True\nPass', (7378, 6094): 'False\nPass', (7378, 7165): 'False\nPass', (7378, 9199): 'False\nPass', (7378, 453): 'True\nPass', (7378, 6114): 'True\nPass', (7378, 7378): 'False\nPass'}
# Example 99
# Free(GB): 3.83811584
# Free(GB): 1.497694208
# Free(GB): 1.497694208
# Free(GB): 1.497694208
# {(9199, 9199): 'False\nPass', (9199, 1777): 'True\nPass', (9199, 7165): 'False\nPass', (9199, 453): 'False\nPass', (9199, 6817): 'False\nPass', (9199, 6114): 'False\nPass', (9199, 9125): 'False\nPass', (9199, 9146): 'False\nPass', (1777, 9199): 'True\nPass', (1777, 1777): 'True\nPass', (1777, 7165): 'True\nPass', (1777, 453): 'True\nPass', (1777, 6817): 'True\nPass', (1777, 6114): 'True\nPass', (1777, 9125): 'True\nPass', (1777, 9146): 'True\nPass', (7165, 9199): 'False\nPass', (7165, 1777): 'True\nPass', (7165, 7165): 'True\nPass', (7165, 453): 'True\nPass', (7165, 6817): 'True\nPass', (7165, 6114): 'True\nPass', (7165, 9125): 'True\nPass', (7165, 9146): 'True\nPass', (453, 9199): 'False\nPass', (453, 1777): 'False\nPass', (453, 7165): 'False\nPass', (453, 453): 'False\nPass', (453, 6817): 'False\nPass', (453, 6114): 'False\nPass', (453, 9125): 'False\nPass', (453, 9146): 'False\nPass', (6817, 9199): 'True\nPass', (6817, 1777): 'True\nPass', (6817, 7165): 'True\nPass', (6817, 453): 'True\nPass', (6817, 6817): 'True\nPass', (6817, 6114): 'True\nPass', (6817, 9125): 'True\nPass', (6817, 9146): 'True\nPass', (6114, 9199): 'False\nPass', (6114, 1777): 'False\nPass', (6114, 7165): 'False\nPass', (6114, 453): 'False\nPass', (6114, 6817): 'False\nPass', (6114, 6114): 'False\nPass', (6114, 9125): 'False\nPass', (6114, 9146): 'False\nPass', (9125, 9199): 'False\nPass', (9125, 1777): 'False\nPass', (9125, 7165): 'False\nPass', (9125, 453): 'False\nPass', (9125, 6817): 'False\nPass', (9125, 6114): 'False\nPass', (9125, 9125): 'False\nPass', (9125, 9146): 'False\nPass', (9146, 9199): 'False\nPass', (9146, 1777): 'True\nPass', (9146, 7165): 'True\nPass', (9146, 453): 'False\nPass', (9146, 6817): 'True\nPass', (9146, 6114): 'False\nPass', (9146, 9125): 'False\nPass', (9146, 9146): 'Yes\nPass'}
7165, 69): 'True\nPass', (7165, 3554): 'True\nPass', (7165, 7165): 'True\nPass', (7165, 6114): 'False\nPass', (7165, 9199): 'False\nPass', (7165, 2342): 'False\nPass', (7165, 7378): 'True\nPass', (6114, 453): 'False\nPass', (6114, 69): 'False\nPass', (6114, 3554): 'False\nPass', (6114, 7165): 'False\nPass', (6114, 6114): 'False\nPass', (6114, 9199): 'False\nPass', (6114, 2342): 'False\nPass', (6114, 7378): 'False\nPass', (9199, 453): 'False\nPass', (9199, 69): 'False\nPass', (9199, 3554): 'False\nPass', (9199, 7165): 'False\nPass', (9199, 6114): 'False\nPass', (9199, 9199): 'False\nPass', (9199, 2342): 'False\nPass', (9199, 7378): 'False\nPass', (2342, 453): 'False\nPass', (2342, 69): 'False\nPass', (2342, 3554): 'False\nPass', (2342, 7165): 'False\nPass', (2342, 6114): 'False\nPass', (2342, 9199): 'False\nPass', (2342, 2342): 'False\nPass', (2342, 7378): 'False\nPass', (7378, 453): 'True\nPass', (7378, 69): 'True\nPass', (7378, 3554): 'True\nPass', (7378, 7165): 'True\nPass', (7378, 6114): 'True\nPass', (7378, 9199): 'False\nPass', (7378, 2342): 'True\nPass', (7378, 7378): 'True\nPass'}
# Example 158
# Free(GB): 1.497694208
# Free(GB): 1.497694208
# Free(GB): 1.497694208
# Free(GB): 1.497694208
# {(69, 69): 'True\nPass', (69, 6817): 'True\nPass', (69, 6114): 'True\nPass', (69, 9125): 'True\nPass', (69, 7165): 'True\nPass', (69, 453): 'True\nPass', (69, 9199): 'True\nPass', (69, 7378): 'True\nPass', (6817, 69): 'True\nPass', (6817, 6817): 'True\nPass', (6817, 6114): 'True\nPass', (6817, 9125): 'True\nPass', (6817, 7165): 'True\nPass', (6817, 453): 'True\nPass', (6817, 9199): 'True\nPass', (6817, 7378): 'True\nPass', (6114, 69): 'False\nPass', (6114, 6817): 'False\nPass', (6114, 6114): 'False\nPass', (6114, 9125): 'False\nPass', (6114, 7165): 'False\nPass', (6114, 453): 'False\nPass', (6114, 9199): 'False\nPass', (6114, 7378): 'False\nPass', (9125, 69): 'False\nPass', (9125, 6817): 'False\nPass', (9125, 6114): 'False\nPass', (9125, 9125): 'False\nPass', (9125, 7165): 'False\nPass', (9125, 453): 'False\nPass', (9125, 9199): 'False\nPass', (9125, 7378): 'False\nPass', (7165, 69): 'True\nPass', (7165, 6817): 'True\nPass', (7165, 6114): 'True\nPass', (7165, 9125): 'True\nPass', (7165, 7165): ' True\nPass', (7165, 453): 'True\nPass', (7165, 9199): 'True\nPass', (7165, 7378): 'True\nPass', (453, 69): 'False\nPass', (453, 6817): 'False\nPass', (453, 6114): 'False\nPass', (453, 9125): 'False\nPass', (453, 7165): 'False\nPass', (453, 453): 'False\nPass', (453, 9199): 'False\nPass', (453, 7378): 'False\nPass', (9199, 69): 'False\nPass', (9199, 6817): 'False\nPass', (9199, 6114): 'False\nPass', (9199, 9125): 'False\nPass', (9199, 7165): 'False\nPass', (9199, 453): 'False\nPass', (9199, 9199): 'False\nPass', (9199, 7378): 'False\nPass', (7378, 69): 'True\nPass', (7378, 6817): 'True\nPass', (7378, 6114): 'True\nPass', (7378, 9125): 'True\nPass', (7378, 7165): 'True\nPass', (7378, 453): 'True\nPass', (7378, 9199): 'True\nPass', (7378, 7378): 'True\nPass'}
nPass', (6114, 9199): 'False\nPass', (6114, 6114): 'False\nPass', (6114, 9146): 'True\nPass', (6114, 69): 'False\nPass', (6114, 9125): 'False\nPass', (6114, 1777): 'False\nPass', (6114, 2342): 'False\nPass', (9146, 7378): 'True\nPass', (9146, 9199): 'False\nPass', (9146, 6114): 'False\nPass', (9146, 9146): 'Yes\nPass', (9146, 69): 'True\nPass', (9146, 9125): 'False\nPass', (9146, 1777): 'True\nPass', (9146, 2342): 'False\nPass', (69, 7378): 'True\nPass', (69, 9199): 'True\nPass', (69, 6114): 'True\nPass', (69, 9146): 'True\nPass', (69, 69): 'True\nPass', (69, 9125): 'True\nPass', (69, 1777): 'True\nPass', (69, 2342): 'True\nPass', (9125, 7378): 'False\nPass', (9125, 9199): 'False\nPass', (9125, 6114): 'False\nPass', (9125, 9146): 'True\nPass', (9125, 69): 'False\nPass', (9125, 9125): 'False\nPass', (9125, 1777): 'False\nPass', (9125, 2342): 'False\nPass', (1777, 7378): 'True\nPass', (1777, 9199): 'True\nPass', (1777, 6114): 'True\nPass', (1777, 9146): 'True\nPass', (1777, 69): 'True\nPass', (1777, 9125): 'False\nPass', (1777, 1777): 'True\nPass', (1777, 2342): 'True\nPass', (2342, 7378): 'True\nPass', (2342, 9199): 'False\nPass', (2342, 6114): 'False\nPass', (2342, 9146): 'True\nPass', (2342, 69): 'True\nPass', (2342, 9125): 'False\nPass', (2342, 1777): 'True\nPass', (2342, 2342): 'False\nPass'}
# Example 258

# %%
print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 1            |        cudaMalloc retries: 2         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |   36388 MB |   43081 MB |    2989 GB |    2954 GB |
# |       from large pool |   36380 MB |   43073 MB |    2968 GB |    2933 GB |
# |       from small pool |       8 MB |      10 MB |      21 GB |      21 GB |
# |---------------------------------------------------------------------------|
# | Active memory         |   36388 MB |   43081 MB |    2989 GB |    2954 GB |
# |       from large pool |   36380 MB |   43073 MB |    2968 GB |    2933 GB |
# |       from small pool |       8 MB |      10 MB |      21 GB |      21 GB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |   37490 MB |   44510 MB |   48654 MB |   11164 MB |
# |       from large pool |   37480 MB |   44498 MB |   48640 MB |   11160 MB |
# |       from small pool |      10 MB |      12 MB |      14 MB |       4 MB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |    1101 MB |    2155 MB |  584810 MB |  583708 MB |
# |       from large pool |    1099 MB |    2152 MB |  560366 MB |  559266 MB |
# |       from small pool |       1 MB |       2 MB |   24443 MB |   24441 MB |
# |---------------------------------------------------------------------------|
# | Allocations           |     634    |     738    |   73840    |   73206    |
# |       from large pool |     297    |     393    |   21107    |   20810    |
# |       from small pool |     337    |     346    |   52733    |   52396    |
# |---------------------------------------------------------------------------|
# | Active allocs         |     634    |     738    |   73840    |   73206    |
# |       from large pool |     297    |     393    |   21107    |   20810    |
# |       from small pool |     337    |     346    |   52733    |   52396    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |     241    |     328    |     349    |     108    |
# |       from large pool |     236    |     322    |     342    |     106    |
# |       from small pool |       5    |       6    |       7    |       2    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |      33    |     129    |   47316    |   47283    |
# |       from large pool |      24    |     118    |   17475    |   17451    |
# |       from small pool |       9    |      12    |   29841    |   29832    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
outputs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 outputs
#
# NameError: name 'outputs' is not defined

# %%
print(torch.cuda.mem_get_info()[0] / (10**9))
gc.collect()
print(torch.cuda.mem_get_info()[0] / (10**9))
torch.cuda.empty_cache()
print(torch.cuda.mem_get_info()[0] / (10**9))
# Out:
# 7.432634368
# 7.432634368
# 7.432634368

# %%
i = 0
others = 0
parameters = 0
for obj in gc.get_objects():
    try:
        if torch.is_tensor(obj) or (hasattr(obj, 'data') and torch.is_tensor(obj.data)):
            print(type(obj), obj.size(), obj.get_device(), obj.storage().nbytes() / 10 **9)
            if isinstance(obj, torch.nn.parameter.Parameter):
                parameters+= obj.storage().nbytes()
            else:
                others+= obj.storage().nbytes()
            i+=1
    except:
        pass
print("Tensors", i)
print("Parameters(GB)", parameters / 10 **9)
print("Others(GB)", others / 10 **9)
# Out:
# <class 'torch.nn.parameter.Parameter'> torch.Size([50272, 4096]) 0 0.823656448
# <class 'torch.nn.parameter.Parameter'> torch.Size([2050, 4096]) 0 0.0335872
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096, 16384]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4096]) 0 1.6384e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384, 4096]) 0 0.268435456
# <class 'torch.nn.parameter.Parameter'> torch.Size([16384]) 0 6.5536e-05
# <class 'torch.nn.parameter.Parameter'> torch.Size([4
# <class 'torch.Tensor'> torch.Size([8, 1]) 0 4.6592e-05
# <class 'torch.Tensor'> torch.Size([8, 727, 50272]) 0 1.169527808
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 32, 727, 128]) 0 0.095289344
# <class 'torch.Tensor'> torch.Size([8, 1]) 0 4.6592e-05
# <class 'torch.Tensor'> torch.Size([8, 1, 1, 728]) 0 2.3296e-05
# <class 'torch.Tensor'> torch.Size([8, 1, 4096]) 0 0.000131072
# <class 'torch.Tensor'> torch.Size([8, 1, 4096]) 0 0.000131072
# <class 'torch.Tensor'> torch.Size([8, 1, 4096]) 0 0.000131072
# <class 'torch.Tensor'> torch.Size([8, 1, 4096]) 0 0.000131072
# <class 'torch.Tensor'> torch.Size([8, 32, 728, 128]) 0 0.095420416
# <class 'torch.Tensor'> torch.Size([8, 32, 728, 128]) 0 0.095420416
# <class 'torch.Tensor'> torch.Size([8, 32, 728, 128]) 0 0.095420416
